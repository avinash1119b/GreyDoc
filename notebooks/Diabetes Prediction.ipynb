# %% [markdown]
# # **Diabetes Prediction**

# %% [markdown]
# ## I. Importing essential libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

import os
print(os.listdir())

import warnings
warnings.filterwarnings('ignore')
# Out:
# ['.config', 'diabetes_model.sav', 'diabetes1.csv', 'sample_data']

# %% [markdown]
# ## II. Importing and understanding our dataset

# %%
dataset = pd.read_csv("/content/diabetes1.csv")

# %% [markdown]
# #### Verifying it as a 'dataframe' object in pandas

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### Shape of dataset

# %%
dataset.shape
# Out:
# (768, 9)

# %% [markdown]
# #### Printing out a few columns

# %%
dataset.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  target
# 0                     0.627   50       1
# 1                     0.351   31       0
# 2                     0.672   32       1
# 3                     0.167   21       0
# 4                     2.288   33       1

# %%
dataset.sample(5)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 675            6      195             70              0        0  30.9
# 106            1       96            122              0        0  22.4
# 499            6      154             74             32      193  29.3
# 149            2       90             70             17        0  27.3
# 51             1      101             50             15       36  24.2
#
#      DiabetesPedigreeFunction  Age  target
# 675                     0.328   31       1
# 106                     0.207   27       0
# 499                     0.839   39       0
# 149                     0.085   22       0
# 51                      0.526   26       0

# %% [markdown]
# #### Description

# %%
dataset.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age      target
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   target                    768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
###Luckily, we have no missing values

# %% [markdown]
# #### Analysing the 'target' variable

# %%
dataset["target"].describe()
# Out:
# count    768.000000
# mean       0.348958
# std        0.476951
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: target, dtype: float64

# %%
dataset["target"].unique()
# Out:
# array([1, 0])

# %% [markdown]
# #### Clearly, this is a classification problem, with the target variable having values '0' and '1'

# %% [markdown]
# ### Checking correlation between columns

# %%
print(dataset.corr()["target"].abs().sort_values(ascending=False))
# Out:
# target                      1.000000
# Glucose                     0.466581
# BMI                         0.292695
# Age                         0.238356
# Pregnancies                 0.221898
# DiabetesPedigreeFunction    0.173844
# Insulin                     0.130548
# SkinThickness               0.074752
# BloodPressure               0.065068
# Name: target, dtype: float64

# %%
#This shows that most columns are moderately correlated with target, but 'fbs' is very weakly correlated.

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### First, analysing the target variable:

# %%
y = dataset["target"]

sns.countplot(y)


target_temp = dataset.target.value_counts()

print(target_temp)
# Out:
# 0    500
# 1    268
# Name: target, dtype: int64

# %%
print("Percentage of patience without heart problems: "+str(round(target_temp[0]*100/303,2)))
print("Percentage of patience with heart problems: "+str(round(target_temp[1]*100/303,2)))

#Alternatively,
# print("Percentage of patience with heart problems: "+str(y.where(y==1).count()*100/303))
# print("Percentage of patience with heart problems: "+str(y.where(y==0).count()*100/303))

# #Or,
# countNoDisease = len(df[df.target == 0])
# countHaveDisease = len(df[df.target == 1])
# Out:
# Percentage of patience without heart problems: 165.02
# Percentage of patience with heart problems: 88.45

# %% [markdown]
# ## IV. Train Test split

# %%
from sklearn.model_selection import train_test_split

predictors = dataset.drop("target",axis=1)
target = dataset["target"]

X_train,X_test,Y_train,Y_test = train_test_split(predictors,target,test_size=0.20,random_state=0)

# %%
X_train.shape
# Out:
# (614, 8)

# %%
X_test.shape
# Out:
# (154, 8)

# %%
Y_train.shape
# Out:
# (614,)

# %%
Y_test.shape
# Out:
# (154,)

# %% [markdown]
# ## V. Model Fitting

# %%
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()

lr.fit(X_train,Y_train)

Y_pred_lr = lr.predict(X_test)

# %%
Y_pred_lr.shape
# Out:
# (154,)

# %%
score_lr = round(accuracy_score(Y_pred_lr,Y_test)*100,2)

print("The accuracy score achieved using Logistic Regression is: "+str(score_lr)+" %")
# Out:
# The accuracy score achieved using Logistic Regression is: 82.47 %

# %% [markdown]
# ### Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

nb = GaussianNB()

nb.fit(X_train,Y_train)

Y_pred_nb = nb.predict(X_test)

# %%
Y_pred_nb.shape
# Out:
# (154,)

# %%
score_nb = round(accuracy_score(Y_pred_nb,Y_test)*100,2)

print("The accuracy score achieved using Naive Bayes is: "+str(score_nb)+" %")
# Out:
# The accuracy score achieved using Naive Bayes is: 79.22 %

# %% [markdown]
# ### SVM

# %%
from sklearn import svm

sv = svm.SVC(kernel='linear')

sv.fit(X_train, Y_train)

Y_pred_svm = sv.predict(X_test)

# %%
Y_pred_svm.shape
# Out:
# (154,)

# %%
score_svm = round(accuracy_score(Y_pred_svm,Y_test)*100,2)

print("The accuracy score achieved using Linear SVM is: "+str(score_svm)+" %")
# Out:
# The accuracy score achieved using Linear SVM is: 81.82 %

# %% [markdown]
# ### K Nearest Neighbors

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(X_train,Y_train)
Y_pred_knn=knn.predict(X_test)

# %%
Y_pred_knn.shape
# Out:
# (154,)

# %%
score_knn = round(accuracy_score(Y_pred_knn,Y_test)*100,2)

print("The accuracy score achieved using KNN is: "+str(score_knn)+" %")
# Out:
# The accuracy score achieved using KNN is: 75.97 %

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

max_accuracy = 0


for x in range(200):
    dt = DecisionTreeClassifier(random_state=x)
    dt.fit(X_train,Y_train)
    Y_pred_dt = dt.predict(X_test)
    current_accuracy = round(accuracy_score(Y_pred_dt,Y_test)*100,2)
    if(current_accuracy>max_accuracy):
        max_accuracy = current_accuracy
        best_x = x

#print(max_accuracy)
#print(best_x)


dt = DecisionTreeClassifier(random_state=best_x)
dt.fit(X_train,Y_train)
Y_pred_dt = dt.predict(X_test)

# %%
print(Y_pred_dt.shape)
# Out:
# (154,)

# %%
score_dt = round(accuracy_score(Y_pred_dt,Y_test)*100,2)

print("The accuracy score achieved using Decision Tree is: "+str(score_dt)+" %")
# Out:
# The accuracy score achieved using Decision Tree is: 81.82 %

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

max_accuracy = 0


for x in range(2000):
    rf = RandomForestClassifier(random_state=x)
    rf.fit(X_train,Y_train)
    Y_pred_rf = rf.predict(X_test)
    current_accuracy = round(accuracy_score(Y_pred_rf,Y_test)*100,2)
    if(current_accuracy>max_accuracy):
        max_accuracy = current_accuracy
        best_x = x

#print(max_accuracy)
#print(best_x)

rf = RandomForestClassifier(random_state=best_x)
rf.fit(X_train,Y_train)
Y_pred_rf = rf.predict(X_test)

# %%
Y_pred_rf.shape
# Out:
# (154,)

# %%
score_rf = round(accuracy_score(Y_pred_rf,Y_test)*100,2)

print("The accuracy score achieved using Decision Tree is: "+str(score_rf)+" %")
# Out:
# The accuracy score achieved using Decision Tree is: 83.77 %

# %% [markdown]
# ### XGBoost

# %%
import xgboost as xgb

xgb_model = xgb.XGBClassifier(objective="binary:logistic", random_state=42)
xgb_model.fit(X_train, Y_train)

Y_pred_xgb = xgb_model.predict(X_test)

# %%
Y_pred_xgb.shape
# Out:
# (154,)

# %%
score_xgb = round(accuracy_score(Y_pred_xgb,Y_test)*100,2)

print("The accuracy score achieved using XGBoost is: "+str(score_xgb)+" %")
# Out:
# The accuracy score achieved using XGBoost is: 79.87 %

# %% [markdown]
# ### Neural Network

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
# https://stats.stackexchange.com/a/136542 helped a lot in avoiding overfitting

model = Sequential()
model.add(Dense(11,activation='relu',input_dim=8))
model.add(Dense(1,activation='sigmoid'))

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.fit(X_train,Y_train,epochs=300)
# Out:
# Epoch 1/300
# 20/20 [==============================] - 1s 3ms/step - loss: 20.8347 - accuracy: 0.6401
# Epoch 2/300
# 20/20 [==============================] - 0s 4ms/step - loss: 14.9278 - accuracy: 0.6401
# Epoch 3/300
# 20/20 [==============================] - 0s 3ms/step - loss: 10.0282 - accuracy: 0.5603
# Epoch 4/300
# 20/20 [==============================] - 0s 3ms/step - loss: 8.1344 - accuracy: 0.5505
# Epoch 5/300
# 20/20 [==============================] - 0s 3ms/step - loss: 6.7265 - accuracy: 0.5375
# Epoch 6/300
# 20/20 [==============================] - 0s 3ms/step - loss: 5.3138 - accuracy: 0.5309
# Epoch 7/300
# 20/20 [==============================] - 0s 4ms/step - loss: 4.1629 - accuracy: 0.5147
# Epoch 8/300
# 20/20 [==============================] - 0s 3ms/step - loss: 3.4107 - accuracy: 0.5130
# Epoch 9/300
# 20/20 [==============================] - 0s 3ms/step - loss: 2.9633 - accuracy: 0.5212
# Epoch 10/300
# 20/20 [==============================] - 0s 3ms/step - loss: 2.6251 - accuracy: 0.5326
# Epoch 11/300
# 20/20 [==============================] - 0s 3ms/step - loss: 2.3639 - accuracy: 0.5228
# Epoch 12/300
# 20/20 [==============================] - 0s 3ms/step - loss: 2.0907 - accuracy: 0.5472
# Epoch 13/300
# 20/20 [==============================] - 0s 3ms/step - loss: 1.8715 - accuracy: 0.5554
# Epoch 14/300
# 20/20 [==============================] - 0s 3ms/step - loss: 1.7062 - accuracy: 0.5554
# Epoch 15/300
# 20/20 [==============================] - 0s 3ms/step - loss: 1.5406 - accuracy: 0.5570
# Epoch 16/300
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4402 - accuracy: 0.5554
# Epoch 17/300
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3297 - accuracy: 0.5831
# Epoch 18/300
# 20/20 [==============================] - 0s 3ms/step - loss: 1.2795 - accuracy: 0.5749
# Epoch 19/300
# 20/20 [==============================] - 0s 4ms/step - loss: 1.2268 - accuracy: 0.5814
# Epoch 20/300
# 20/20 [==============================] - 0s 4ms/step - loss: 1.1740 - accuracy: 0.5977
# Epoch 21/300
# 20/20 [==============================] - 0s 3ms/step - loss: 1.1374 - accuracy: 0.5912
# Epoch 22/300
# 20/20 [==============================] - 0s 4ms/step - loss: 1.1072 - accuracy: 0.6124
# Epoch 23/300
# 20/20 [==============================] - 0s 3ms/step - loss: 1.0624 - accuracy: 0.6010
# Epoch 24/300
# 20/20 [==============================] - 0s 3ms/step - loss: 1.0428 - accuracy: 0.5863
# Epoch 25/300
# 20/20 [==============================] - 0s 3ms/step - loss: 1.0159 - accuracy: 0.6238
# Epoch 26/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.9899 - accuracy: 0.6140
# Epoch 27/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.9531 - accuracy: 0.6124
# Epoch 28/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.9361 - accuracy: 0.6124
# Epoch 29/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.9426 - accuracy: 0.6221
# Epoch 30/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.8894 - accuracy: 0.6287
# Epoch 31/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.8926 - accuracy: 0.6173
# Epoch 32/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.8829 - accuracy: 0.6368
# Epoch 33/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.8550 - accuracy: 0.6189
# Epoch 34/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.8368 - accuracy: 0.6254
# Epoch 35/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.8470 - accuracy: 0.6319
# Epoch 36/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.8248 - accuracy: 0.6384
# Epoch 37/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.7926 - accuracy: 0.6384
# Epoch 38/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.7952 - accuracy: 0.6368
# Epoch 39/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.7755 - accuracy: 0.6450
# Epoch 40/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.7760 - accuracy: 0.6384
# Epoch 41/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.7622 - accuracy: 0.6401
# Epoch 42/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.7480 - accuracy: 0.6466
# Epoch 43/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.7518 - accuracy: 0.6254
# Epoch 44/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.7503 - accuracy: 0.6580
# Epoch 45/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.7376 - accuracy: 0.6401
# Epoch 46/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.7270 - accuracy: 0.6531
# Epoch 47/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.7368 - accuracy: 0.6531
# Epoch 48/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.7194 - accuracy: 0.6612
# Epoch 49/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.7172 - accuracy: 0.6678
# Epoch 50/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.7075 - accuracy: 0.6564
# Epoch 51/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.7094 - accuracy: 0.6694
# Epoch 52/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.7122 - accuracy: 0.6612
# Epoch 53/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.7235 - accuracy: 0.6515
# Epoch 54/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6923 - accuracy: 0.6743
# Epoch 55/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6905 - accuracy: 0.6726
# Epoch 56/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6960 - accuracy: 0.6775
# Epoch 57/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6892 - accuracy: 0.6661
# Epoch 58/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6836 - accuracy: 0.6824
# Epoch 59/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6879 - accuracy: 0.6726
# Epoch 60/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6909 - accuracy: 0.6531
# Epoch 61/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6972 - accuracy: 0.6596
# Epoch 62/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6738 - accuracy: 0.6792
# Epoch 63/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6690 - accuracy: 0.6954
# Epoch 64/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6632 - accuracy: 0.6726
# Epoch 65/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6840 - accuracy: 0.6710
# Epoch 66/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6606 - accuracy: 0.6873
# Epoch 67/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6628 - accuracy: 0.6922
# Epoch 68/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6659 - accuracy: 0.6824
# Epoch 69/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6750 - accuracy: 0.6596
# Epoch 70/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6631 - accuracy: 0.6645
# Epoch 71/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6557 - accuracy: 0.6840
# Epoch 72/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6709 - accuracy: 0.6775
# Epoch 73/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6526 - accuracy: 0.6857
# Epoch 74/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6559 - accuracy: 0.6645
# Epoch 75/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6550 - accuracy: 0.6775
# Epoch 76/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6623 - accuracy: 0.6629
# Epoch 77/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6347 - accuracy: 0.6889
# Epoch 78/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6542 - accuracy: 0.6971
# Epoch 79/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6535 - accuracy: 0.6808
# Epoch 80/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6718 - accuracy: 0.6824
# Epoch 81/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6508 - accuracy: 0.6645
# Epoch 82/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6490 - accuracy: 0.6889
# Epoch 83/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6367 - accuracy: 0.6808
# Epoch 84/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6379 - accuracy: 0.6808
# Epoch 85/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6441 - accuracy: 0.6775
# Epoch 86/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6346 - accuracy: 0.6824
# Epoch 87/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6601 - accuracy: 0.6645
# Epoch 88/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6271 - accuracy: 0.6840
# Epoch 89/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6194 - accuracy: 0.6906
# Epoch 90/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6604 - accuracy: 0.6726
# Epoch 91/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6315 - accuracy: 0.6645
# Epoch 92/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6806 - accuracy: 0.6580
# Epoch 93/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6310 - accuracy: 0.6661
# Epoch 94/300
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6174 - accuracy: 0.6971
# Epoch 95/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6255 - accuracy: 0.6743
# Epoch 96/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6102 - accuracy: 0.7003
# Epoch 97/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6067 - accuracy: 0.6906
# Epoch 98/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6079 - accuracy: 0.7068
# Epoch 99/300
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6107 - accuracy: 0.6857
# Epoch 100/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6096 - accuracy: 0.6873
# Epoch 101/300
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6079 - accuracy: 0.6922
# Epoch 102/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6065 - accuracy: 0.6954
# Epoch 103/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6142 - accuracy: 0.6889
# Epoch 104/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6073 - accuracy: 0.6889
# Epoch 105/300
# 20/20 [==============================] - 0s 6ms/step - loss: 0.6100 - accuracy: 0.6824
# Epoch 106/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6011 - accuracy: 0.6954
# Epoch 107/300
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6129 - accuracy: 0.6775
# Epoch 108/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5879 - accuracy: 0.7052
# Epoch 109/300
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5934 - accuracy: 0.6938
# Epoch 110/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5969 - accuracy: 0.7117
# Epoch 111/300
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6050 - accuracy: 0.6906
# Epoch 112/300
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5867 - accuracy: 0.6971
# Epoch 113/300
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5812 - accuracy: 0.6759
# Epoch 114/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5734 - accuracy: 0.6954
# Epoch 115/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5717 - accuracy: 0.6987
# Epoch 116/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5704 - accuracy: 0.7134
# Epoch 117/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5754 - accuracy: 0.6906
# Epoch 118/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5773 - accuracy: 0.7068
# Epoch 119/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5732 - accuracy: 0.7068
# Epoch 120/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5736 - accuracy: 0.6922
# Epoch 121/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5992 - accuracy: 0.6775
# Epoch 122/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6067 - accuracy: 0.6840
# Epoch 123/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5685 - accuracy: 0.7231
# Epoch 124/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5755 - accuracy: 0.7101
# Epoch 125/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5913 - accuracy: 0.6678
# Epoch 126/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5902 - accuracy: 0.7085
# Epoch 127/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5660 - accuracy: 0.7068
# Epoch 128/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5994 - accuracy: 0.6922
# Epoch 129/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5989 - accuracy: 0.6792
# Epoch 130/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5769 - accuracy: 0.6873
# Epoch 131/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5652 - accuracy: 0.7296
# Epoch 132/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5749 - accuracy: 0.7101
# Epoch 133/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5705 - accuracy: 0.7036
# Epoch 134/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5571 - accuracy: 0.7182
# Epoch 135/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5636 - accuracy: 0.7150
# Epoch 136/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6174 - accuracy: 0.6873
# Epoch 137/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5910 - accuracy: 0.7052
# Epoch 138/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6006 - accuracy: 0.6596
# Epoch 139/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5497 - accuracy: 0.7329
# Epoch 140/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5693 - accuracy: 0.7020
# Epoch 141/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5570 - accuracy: 0.7248
# Epoch 142/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5588 - accuracy: 0.7329
# Epoch 143/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5922 - accuracy: 0.6889
# Epoch 144/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5742 - accuracy: 0.7052
# Epoch 145/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5528 - accuracy: 0.7231
# Epoch 146/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5619 - accuracy: 0.7150
# Epoch 147/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5520 - accuracy: 0.7231
# Epoch 148/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5642 - accuracy: 0.7036
# Epoch 149/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5769 - accuracy: 0.6743
# Epoch 150/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5761 - accuracy: 0.7248
# Epoch 151/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5661 - accuracy: 0.7052
# Epoch 152/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5570 - accuracy: 0.7182
# Epoch 153/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5664 - accuracy: 0.7036
# Epoch 154/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5493 - accuracy: 0.7215
# Epoch 155/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5516 - accuracy: 0.7215
# Epoch 156/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5584 - accuracy: 0.7182
# Epoch 157/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5538 - accuracy: 0.7134
# Epoch 158/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5565 - accuracy: 0.7166
# Epoch 159/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5741 - accuracy: 0.7068
# Epoch 160/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5718 - accuracy: 0.7166
# Epoch 161/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5608 - accuracy: 0.7117
# Epoch 162/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5646 - accuracy: 0.7248
# Epoch 163/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5605 - accuracy: 0.7036
# Epoch 164/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5592 - accuracy: 0.7052
# Epoch 165/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5531 - accuracy: 0.7345
# Epoch 166/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5585 - accuracy: 0.7182
# Epoch 167/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5585 - accuracy: 0.7215
# Epoch 168/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5484 - accuracy: 0.7264
# Epoch 169/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5469 - accuracy: 0.7166
# Epoch 170/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5897 - accuracy: 0.6857
# Epoch 171/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5733 - accuracy: 0.7150
# Epoch 172/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5721 - accuracy: 0.7166
# Epoch 173/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5618 - accuracy: 0.7101
# Epoch 174/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5506 - accuracy: 0.7313
# Epoch 175/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5440 - accuracy: 0.7150
# Epoch 176/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5437 - accuracy: 0.7313
# Epoch 177/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5481 - accuracy: 0.7182
# Epoch 178/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5434 - accuracy: 0.7215
# Epoch 179/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5711 - accuracy: 0.6922
# Epoch 180/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5762 - accuracy: 0.7036
# Epoch 181/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5462 - accuracy: 0.7427
# Epoch 182/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5699 - accuracy: 0.7068
# Epoch 183/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5435 - accuracy: 0.7313
# Epoch 184/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5430 - accuracy: 0.7264
# Epoch 185/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5634 - accuracy: 0.7150
# Epoch 186/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5554 - accuracy: 0.7248
# Epoch 187/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5850 - accuracy: 0.7199
# Epoch 188/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5577 - accuracy: 0.7231
# Epoch 189/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5388 - accuracy: 0.7345
# Epoch 190/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5371 - accuracy: 0.7394
# Epoch 191/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5479 - accuracy: 0.7329
# Epoch 192/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5795 - accuracy: 0.6922
# Epoch 193/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5746 - accuracy: 0.7052
# Epoch 194/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5447 - accuracy: 0.7362
# Epoch 195/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5423 - accuracy: 0.7248
# Epoch 196/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5395 - accuracy: 0.7345
# Epoch 197/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5473 - accuracy: 0.7101
# Epoch 198/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5397 - accuracy: 0.7264
# Epoch 199/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5531 - accuracy: 0.7329
# Epoch 200/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5519 - accuracy: 0.7215
# Epoch 201/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5349 - accuracy: 0.7313
# Epoch 202/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5419 - accuracy: 0.7394
# Epoch 203/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5383 - accuracy: 0.7345
# Epoch 204/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5342 - accuracy: 0.7378
# Epoch 205/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5353 - accuracy: 0.7394
# Epoch 206/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5601 - accuracy: 0.7150
# Epoch 207/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5561 - accuracy: 0.7068
# Epoch 208/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5343 - accuracy: 0.7378
# Epoch 209/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5343 - accuracy: 0.7362
# Epoch 210/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5395 - accuracy: 0.7345
# Epoch 211/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5423 - accuracy: 0.7248
# Epoch 212/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5314 - accuracy: 0.7378
# Epoch 213/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5493 - accuracy: 0.7362
# Epoch 214/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5409 - accuracy: 0.7329
# Epoch 215/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5334 - accuracy: 0.7313
# Epoch 216/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5448 - accuracy: 0.7345
# Epoch 217/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5275 - accuracy: 0.7492
# Epoch 218/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5343 - accuracy: 0.7345
# Epoch 219/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5344 - accuracy: 0.7345
# Epoch 220/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5375 - accuracy: 0.7313
# Epoch 221/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5583 - accuracy: 0.6954
# Epoch 222/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5406 - accuracy: 0.7362
# Epoch 223/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5389 - accuracy: 0.7329
# Epoch 224/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5378 - accuracy: 0.7410
# Epoch 225/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5639 - accuracy: 0.7117
# Epoch 226/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5758 - accuracy: 0.7068
# Epoch 227/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5312 - accuracy: 0.7329
# Epoch 228/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5544 - accuracy: 0.7199
# Epoch 229/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5449 - accuracy: 0.7394
# Epoch 230/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5462 - accuracy: 0.7182
# Epoch 231/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5357 - accuracy: 0.7329
# Epoch 232/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5284 - accuracy: 0.7345
# Epoch 233/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5337 - accuracy: 0.7410
# Epoch 234/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5916 - accuracy: 0.6840
# Epoch 235/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5433 - accuracy: 0.7329
# Epoch 236/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5251 - accuracy: 0.7524
# Epoch 237/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5249 - accuracy: 0.7427
# Epoch 238/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5340 - accuracy: 0.7329
# Epoch 239/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5294 - accuracy: 0.7427
# Epoch 240/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5468 - accuracy: 0.7231
# Epoch 241/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5284 - accuracy: 0.7655
# Epoch 242/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5258 - accuracy: 0.7459
# Epoch 243/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5234 - accuracy: 0.7329
# Epoch 244/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5277 - accuracy: 0.7410
# Epoch 245/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5324 - accuracy: 0.7313
# Epoch 246/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5582 - accuracy: 0.6987
# Epoch 247/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5326 - accuracy: 0.7443
# Epoch 248/300
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5350 - accuracy: 0.7427
# Epoch 249/300
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5583 - accuracy: 0.7166
# Epoch 250/300
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5314 - accuracy: 0.7362
# Epoch 251/300
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5420 - accuracy: 0.7345
# Epoch 252/300
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5409 - accuracy: 0.7134
# Epoch 253/300
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5400 - accuracy: 0.7248
# Epoch 254/300
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5500 - accuracy: 0.7296
# Epoch 255/300
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5487 - accuracy: 0.7231
# Epoch 256/300
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5237 - accuracy: 0.7557
# Epoch 257/300
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5364 - accuracy: 0.7264
# Epoch 258/300
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5367 - accuracy: 0.7394
# Epoch 259/300
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5290 - accuracy: 0.7508
# Epoch 260/300
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5263 - accuracy: 0.7378
# Epoch 261/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5213 - accuracy: 0.7476
# Epoch 262/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5247 - accuracy: 0.7492
# Epoch 263/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5457 - accuracy: 0.7264
# Epoch 264/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5455 - accuracy: 0.7345
# Epoch 265/300
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5607 - accuracy: 0.7410
# Epoch 266/300
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5484 - accuracy: 0.7134
# Epoch 267/300
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5245 - accuracy: 0.7459
# Epoch 268/300
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5228 - accuracy: 0.7492
# Epoch 269/300
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5236 - accuracy: 0.7524
# Epoch 270/300
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5181 - accuracy: 0.7476
# Epoch 271/300
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5292 - accuracy: 0.7573
# Epoch 272/300
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5329 - accuracy: 0.7459
# Epoch 273/300
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5232 - accuracy: 0.7541
# Epoch 274/300
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5232 - accuracy: 0.7606
# Epoch 275/300
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5214 - accuracy: 0.7394
# Epoch 276/300
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5318 - accuracy: 0.7476
# Epoch 277/300
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5304 - accuracy: 0.7280
# Epoch 278/300
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5224 - accuracy: 0.7410
# Epoch 279/300
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5271 - accuracy: 0.7736
# Epoch 280/300
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5281 - accuracy: 0.7557
# Epoch 281/300
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5208 - accuracy: 0.7427
# Epoch 282/300
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5257 - accuracy: 0.7557
# Epoch 283/300
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5834 - accuracy: 0.7020
# Epoch 284/300
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5381 - accuracy: 0.7264
# Epoch 285/300
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5520 - accuracy: 0.7264
# Epoch 286/300
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5590 - accuracy: 0.7101
# Epoch 287/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5292 - accuracy: 0.7541
# Epoch 288/300
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5319 - accuracy: 0.7443
# Epoch 289/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5235 - accuracy: 0.7394
# Epoch 290/300
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5156 - accuracy: 0.7427
# Epoch 291/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5143 - accuracy: 0.7459
# Epoch 292/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5200 - accuracy: 0.7606
# Epoch 293/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5268 - accuracy: 0.7329
# Epoch 294/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5246 - accuracy: 0.7492
# Epoch 295/300
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5128 - accuracy: 0.7655
# Epoch 296/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5471 - accuracy: 0.7296
# Epoch 297/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5439 - accuracy: 0.7296
# Epoch 298/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5189 - accuracy: 0.7524
# Epoch 299/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5206 - accuracy: 0.7459
# Epoch 300/300
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5216 - accuracy: 0.7492

# %%
Y_pred_nn = model.predict(X_test)
# Out:
# 5/5 [==============================] - 0s 2ms/step

# %%
Y_pred_nn.shape
# Out:
# (154, 1)

# %%
rounded = [round(x[0]) for x in Y_pred_nn]

Y_pred_nn = rounded

# %%
score_nn = round(accuracy_score(Y_pred_nn,Y_test)*100,2)

print("The accuracy score achieved using Neural Network is: "+str(score_nn)+" %")

#Note: Accuracy of 85% can be achieved on the test set, by setting epochs=2000, and number of nodes = 11.
# Out:
# The accuracy score achieved using Neural Network is: 77.92 %

# %% [markdown]
# ## VI. Output final score

# %%
scores = [score_lr,score_nb,score_svm,score_knn,score_dt,score_rf,score_xgb,score_nn]
algorithms = ["Logistic Regression","Naive Bayes","Support Vector Machine","K-Nearest Neighbors","Decision Tree","Random Forest","XGBoost","Neural Network"]

for i in range(len(algorithms)):
    print("The accuracy score achieved using "+algorithms[i]+" is: "+str(scores[i])+" %")
# Out:
# The accuracy score achieved using Logistic Regression is: 82.47 %
# The accuracy score achieved using Naive Bayes is: 79.22 %
# The accuracy score achieved using Support Vector Machine is: 81.82 %
# The accuracy score achieved using K-Nearest Neighbors is: 75.97 %
# The accuracy score achieved using Decision Tree is: 81.82 %
# The accuracy score achieved using Random Forest is: 83.77 %
# The accuracy score achieved using XGBoost is: 79.87 %
# The accuracy score achieved using Neural Network is: 77.92 %

# %%
sns.set(rc={'figure.figsize':(15,8)})
plt.xlabel("Algorithms")
plt.ylabel("Accuracy score")

sns.barplot(x=algorithms, y=scores)
# Out:
# <Axes: xlabel='Algorithms', ylabel='Accuracy score'>

# %% [markdown]
# ### Hey arbaaz there random forest has good result as compare to other algorithms <br> <br>

# %%
input_data = (8,183,64,0,0,23.3,0.672,32)

# changing input data to a numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the numpy array
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = rf.predict(input_data_reshaped)
print(prediction)


if (prediction[0] == 0):
  print("The Person does not have Diabetes")

else:
  print("The Person has Diabetes")
# Out:
# [1]
# The Person has Diabetes

# %%
import pickle

# %%
filename = 'diabetes_model.sav'
pickle.dump(rf, open(filename, 'wb'))

# %%
# loading the saved model
loaded_model = pickle.load(open('diabetes_model.sav', 'rb'))

# %%
input_data = (1,89,66,23,94,28.1,0.167,21)

# changing the input_data to numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the array as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = loaded_model.predict(input_data_reshaped)
print(prediction)

if (prediction[0] == 0):
  print('The person is not diabetic')
else:
  print('The person is diabetic')
# Out:
# [0]
# The person is not diabetic
